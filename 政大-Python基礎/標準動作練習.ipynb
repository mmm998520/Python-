# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 將點連成一線

# %%
plt.plot([-1,2,-8,1,9,-12,3,5])

# %% [markdown]
# 將 "100個" "平均是0" "標準差是1" 的點連成一線

# %%
plt.plot(np.random.randn(100))
